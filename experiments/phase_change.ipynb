# %%
import torch
from occhio import ToyModel
from occhio.model_grid import ModelGrid, Axis
from occhio.autoencoder import TiedLinearRelu
from occhio.distributions import CorrelatedPairs, HierarchicalPairs, AnticorrelatedPairs 
from occhio.visualization.phase_change import plot_phase_change, plot_phase_change_multi
from occhio.visualization.export import export_figure

# %%
N_FEATURES = 6
N_HIDDEN = 2
P_INDIVIDUAL = 1
P_FOLLOW = 1
DATA = "correlated_pairs_corr_sweep"
EXPERIMENT_SIZE = 16

# %%
densities = torch.logspace(0.0, -1.0, EXPERIMENT_SIZE)
p_inds = torch.linspace(0.2, 1.0, EXPERIMENT_SIZE)

# %%
# causal = torch.Tensor(
#         [
#             [0.0, 1.0],
#             [0.0, 0.0],
#         ],
#     )

def model_trainer(density, p_individual):
    generator = torch.Generator("cpu")
    generator.manual_seed(42)
    distribution=CorrelatedPairs(
        N_FEATURES,p_active=density, p_individual=p_individual, generator=generator
    )

    model = ToyModel(
        distribution=distribution,
        ae=TiedLinearRelu(N_FEATURES, N_HIDDEN, generator=generator),
        importances=0.9 ** torch.arange(N_FEATURES),
    )
    model.fit(n_epochs=8000)
    return model


model_grid = ModelGrid(
    model_trainer,
    x_axis=Axis("p_individual", p_inds),
    y_axis=Axis("Density", densities),
)

# %%
fig = plot_phase_change_multi(model_grid, up_to=6, max_cols= 4)
fig.show()

# %%
export_figure(
    fig,
    {"data": DATA, "p_individual": P_INDIVIDUAL},
    # {"data": DATA, "p_follow": P_FOLLOW},
    subdir="phase-changes",
)
