# %%
import torch
from torch import Generator
from occhio import ToyModel
from occhio.model_grid import ModelGrid, Axis
from occhio.autoencoder import TiedLinearRelu
from occhio.distributions import CorrelatedPairs, HierarchicalPairs, SparseUniform
from occhio.visualization.phase_change import plot_phase_change
from occhio.visualization.export import export_figure

# %%
generator = torch.Generator("cpu").manual_seed(42)

# %%
N_FEATURES = 2
N_HIDDEN = 1
P_INDIVIDUAL = 1
P_FOLLOW = 1
DATA = "correlated_pairs"
EXPERIMENT_SIZE = 20

# %%
densities = torch.logspace(0, -2, EXPERIMENT_SIZE)
importances = torch.logspace(-1, 1, EXPERIMENT_SIZE)

# %%
def create_model(params):
    device = "mps"
    generator = Generator(device=device).manual_seed(42)

    return ToyModel(
        distribution=SparseUniform(
            N_FEATURES,
            p_active=params["Density"],
            # p_individual=P_INDIVIDUAL,
            generator=generator,
            device=device,
        ),
        ae=TiedLinearRelu(N_FEATURES, N_HIDDEN, generator=generator, device=device),
        importances=params["Importance Decay"] ** torch.arange(N_FEATURES),
    )


model_grid = ModelGrid(
    create_model,
    axes=[
        Axis("Importance Decay", importances),
        Axis("Density", densities),
    ],
)

# %%
model_grid.fit(n_epochs=100)
# Out:
# Training: 100%|██████████| 100/100 [00:03<00:00, 33.28epoch/s]

# %%
fig = plot_phase_change(model_grid, tracked_feature=0)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 fig = plot_phase_change(model_grid, tracked_feature=0)
#       2 fig.show()
#
# File ~/dev/professional/lasr/occhio/src/occhio/visualization/phase_change.py:11, in plot_phase_change(model_grid, tracked_feature)
#       9 def plot_phase_change(model_grid: ModelGrid, *, tracked_feature=1):
#      10     if len(model_grid.shape) != 2:
# ---> 11         raise ValueError(
#      12             f"plot_phase_change requires a 2-dimensional ModelGrid, "
#      13             f"got {len(model_grid.shape)}-dimensional (shape: {model_grid.shape})."
#      14         )
#      16     fig = make_subplots(
#      17         rows=1,
#      18         cols=2,
#      19         column_widths=[0.8, 0.2],
#      20         subplot_titles=(f"Phase Change [Feature {tracked_feature}]", "Colormap"),
#      21     )
#      23     _add_model_phases_trace(model_grid, tracked_feature, fig, col=1, row=1)
#
# ValueError: plot_phase_change requires a 2-dimensional ModelGrid, got 3-dimensional (shape: (20, 20, 20)).

# %%
export_figure(
    fig,
    {"data": DATA, "p_individual": P_INDIVIDUAL},
    # {"data": DATA, "p_follow": P_FOLLOW},
    subdir="phase-changes",
)
