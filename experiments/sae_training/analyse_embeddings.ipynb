# %%
from pathlib import Path
from experiments.sae_training.utils import name_embedding_training
from occhio import ModelGrid
from occhio.visualization_2 import (
    plot_feature_representation,
    plot_feature_representation_overlay,
    plot_representation,
)

# %%
NAME = "synth_sae_bench"
N_HIDDEN = 64
N_FEATURES = [350, 400]

# %%
grid = ModelGrid.load(
    Path("grids")
    / name_embedding_training(
        NAME,
        n_hidden=N_HIDDEN,
        n_features=N_FEATURES,
    )
)

# %%
plot_feature_representation(grid, slider_axes=(1,), height=800, width=1000)

# %%
plot_feature_representation_overlay(grid, slider_axes=(1,), height=700)

# %%
plot_representation(grid)
